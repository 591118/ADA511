# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('scatterXY_A.csv')
df
# Out:
#             x         y
# 0   -0.168398  5.558580
# 1    5.254172  3.343994
# 2    0.793347  0.961661
# 3    4.293849  5.112612
# 4    3.599636  2.034885
# ..        ...       ...
# 195  6.797883 -3.240097
# 196  0.826494  2.142307
# 197  0.577950  1.105044
# 198 -0.393809  0.322098
# 199  1.061053  0.727113
#
# [200 rows x 2 columns]

# %%
# Using Matplotlib
plt.figure(figsize=(8, 6))  # Optional: Set the figure size
plt.scatter(df['x'], df['y'])
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatterplot of {} vs {}'.format(df['x'], df['y']))
plt.grid(True)
plt.show()

# Using Seaborn
plt.figure(figsize=(8, 6))  # Optional: Set the figure size
sns.scatterplot(data=df, x=df['x'], y=df['y'])
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatterplot of {} vs {}'.format(df['x'], df['y']))
plt.grid(True)
plt.show()
