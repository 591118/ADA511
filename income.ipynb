# %%
import pandas as pd

# %%
df = pd.read_csv('income_nominal_data_all.csv')
df
# Out:
#               workclass     education      marital_status         occupation  \
# 0               Private  Some-college       Never-married  Machine-op-inspct
# 1               Private  Some-college       Never-married       Adm-clerical
# 2               Private       HS-grad             Widowed    Exec-managerial
# 3             Local-gov  Some-college  Married-civ-spouse   Transport-moving
# 4               Private       HS-grad       Never-married       Craft-repair
# ...                 ...           ...                 ...                ...
# 45217           Private          10th  Married-civ-spouse  Machine-op-inspct
# 45218           Private       HS-grad            Divorced       Craft-repair
# 45219  Self-emp-not-inc       HS-grad  Married-civ-spouse       Craft-repair
# 45220           Private       HS-grad  Married-civ-spouse  Handlers-cleaners
# 45221           Private       HS-grad            Divorced       Craft-repair
#
# ...

# %%
df = df[['sex', 'income']]
df
# Out:
#           sex income
# 0      Female  <=50K
# 1      Female  <=50K
# 2      Female  <=50K
# 3        Male  <=50K
# 4        Male  <=50K
# ...       ...    ...
# 45217    Male  <=50K
# 45218    Male  <=50K
# 45219    Male  <=50K
# 45220    Male  <=50K
# 45221    Male  <=50K
#
# [45222 rows x 2 columns]

# %%
count_men_lte_50k = df[(df['sex'] == 'Male') & (df['income'] == '<=50K')].shape[0]
count_men_gt_50k = df[(df['sex'] == 'Male') & (df['income'] == '>50K')].shape[0]
count_women_lte_50k = df[(df['sex'] == 'Female') & (df['income'] == '<=50K')].shape[0]
count_women_gt_50k = df[(df['sex'] == 'Female') & (df['income'] == '>50K')].shape[0]

# %%
print("Number of men with income <= 50K: ", count_men_lte_50k)
print("Number of men with income > 50K: ", count_men_gt_50k)
print("Number of women with income <= 50K: ", count_women_lte_50k)
print("Number of women with income > 50K: ", count_women_gt_50k)
# Out:
# Number of men with income <= 50K:  20988
# Number of men with income > 50K:  9539
# Number of women with income <= 50K:  13026
# Number of women with income > 50K:  1669

# %%
total = df.shape[0]
print(total)
# Out:
# 45222

# %%
percentage_men_lte_50k = (count_men_lte_50k / total) * 100
percentage_men_gt_50k = (count_men_gt_50k / total) * 100
percentage_women_lte_50k = (count_women_lte_50k / total) * 100
percentage_women_gt_50k = (count_women_gt_50k / total) * 100

# %%
print("Percentage of men with income <= 50K: ", percentage_men_lte_50k)
print("Percentage of men with income > 50K: ", percentage_men_gt_50k)
print("Percentage of women with income <= 50K: ", percentage_women_lte_50k)
print("Percentage of women with income > 50K: ", percentage_women_gt_50k)
# Out:
# Percentage of men with income <= 50K:  46.41103887488391
# Percentage of men with income > 50K:  21.093715448233162
# Percentage of women with income <= 50K:  28.804564150192384
# Percentage of women with income > 50K:  3.6906815266905486

# %%
df = pd.read_csv('income_nominal_data_all.csv')
df
# Out:
#               workclass     education      marital_status         occupation  \
# 0               Private  Some-college       Never-married  Machine-op-inspct
# 1               Private  Some-college       Never-married       Adm-clerical
# 2               Private       HS-grad             Widowed    Exec-managerial
# 3             Local-gov  Some-college  Married-civ-spouse   Transport-moving
# 4               Private       HS-grad       Never-married       Craft-repair
# ...                 ...           ...                 ...                ...
# 45217           Private          10th  Married-civ-spouse  Machine-op-inspct
# 45218           Private       HS-grad            Divorced       Craft-repair
# 45219  Self-emp-not-inc       HS-grad  Married-civ-spouse       Craft-repair
# 45220           Private       HS-grad  Married-civ-spouse  Handlers-cleaners
# 45221           Private       HS-grad            Divorced       Craft-repair
#
# ...

# %%
for column in df.columns:
    print(f"Unique values in column '{column}':\n{df[column].value_counts()}\n")
# Out:
# Unique values in column 'workclass':
# Private             33307
# Self-emp-not-inc     3796
# Local-gov            3100
# State-gov            1946
# Self-emp-inc         1646
# Federal-gov          1406
# Without-pay            21
# Name: workclass, dtype: int64
#
# Unique values in column 'education':
# HS-grad         14783
# Some-college     9899
# Bachelors        7570
# Masters          2514
# Assoc-voc        1959
# 11th             1619
# Assoc-acdm       1507
# 10th             1223
# 7th-8th           823
# Prof-school       785
# 9th               676
# 12th              577
# Doctorate         544
# 5th-6th           449
# 1st-4th           222
# Preschool          72
# Name: education, dtype: int64
#
# Unique values in column 'marital_status':
# Married-civ-spouse       21055
# Never-married            14598
# Divorced                  6297
# Separated                 1411
# Widowed                   1277
# Married-spouse-absent      552
# ...
